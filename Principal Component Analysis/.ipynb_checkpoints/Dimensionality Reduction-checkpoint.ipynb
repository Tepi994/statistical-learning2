# %%
# %matplotlib inline
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import fetch_openml

from sklearn.decomposition import PCA
import imageio as imio

# %%
images_inception_features = './pre-processing/training_inception_features_array.npy'
training_image_labels_array = './pre-processing/training_image_labels_array.npy'
training_image_names_array = './pre-processing/training_image_names_array.npy'
test_features = np.load('./data/test/test_inception_features_array.npy')

# %%
TRAIN_DICTIONARY_KEYS = ["images", "label","features"]

training_set_dict = dict()
    
training_set_dict['images_name'] = np.load(training_image_names_array)
training_set_dict['label'] = np.load(training_image_labels_array)
training_set_dict['features'] = np.load(images_inception_features)

# %%
features = training_set_dict['features']
labels = training_set_dict['label']
images_name = training_set_dict['images_name']

# %%
print('Label: ',labels[4])

print('Nombre: ',images_name[4])

img = imio.imread('./data/train/'+images_name[4]+'.jpg')
plt.imshow(img)
# Out:
# Label:  golden_retriever
# Nombre:  0021f9ceb3235effd7fcde7f7538ed62

# %%
##Amount of labels
np.unique(labels).shape[0]
# Out:
# 120

# %%
#### PCA 2 dimensions ######
x = features
pca = PCA(n_components= 2)
principalComponents = pca.fit_transform(x)
X2D = pd.DataFrame(data = principalComponents, 
                    columns = ['pca_1','pca_2'])
X2D = principalComponents

# %%
print(x.shape)
print(X2D.shape)
# Out:
# (10222, 2048)
# (10222, 2)

# %%
plt.scatter(X2D[:, 0], X2D[:, 1])
plt.xlabel('component 1')
plt.ylabel('component 2')
# Out:
# Text(0, 0.5, 'component 2')

# %%
## K-means
kmeans = KMeans(n_clusters=120)
Km = kmeans.fit(X2D)

# %%
clusters = kmeans.predict(X2D)

# %%
kmeans.cluster_centers_.shape
# Out:
# (120, 2)

# %%
centers = kmeans.cluster_centers_

# %%
plt.figure(figsize=(16,10))
plt.scatter(X2D[:, 0], X2D[:, 1],
             edgecolor='none', alpha=0.5,
            cmap=plt.cm.get_cmap('Accent', 10))
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# ## Comments
# Applying principal component analysis to the dataset and utilizing the first two component results in mapping in a two-dimensional array all of the breeds features. However, it is hard to see if the clusters are on the specific type of breeds.

# %% [markdown]
# ## t-SNE

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2)
tsne_model = tsne.fit_transform(features)

# %%
tsne_predict = tsne.fit_transform(features[1:1000])

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    tsne_predict[:,0], 
    tsne_predict[:,1],
    alpha = 0.7
)

# %% [markdown]
# ## K-means applied to the t-SNE

# %%
## K-means
kmeans_tsne = KMeans(n_clusters=120)
Km_tsne = kmeans_tsne.fit(tsne_model)

# %%
clusters_tsne = kmeans_tsne.predict(tsne_model)

# %%
centers_tsne = kmeans_tsne.cluster_centers_

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    tsne_model[:,0], 
    tsne_model[:,1],
    alpha = 0.7
)
plt.scatter(centers_tsne[:, 0], centers_tsne[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# ## Comments
# As we can see, applying t-SNE to the dataset maps into a two dimensional array all all of the dog breeds. After applying k-means utilizing 120 clusters (all the dogbreeds in the dataset) we can observe that they are cohesive to the transormation applied to the points
